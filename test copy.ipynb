# %%
import ethograph as eto

project = eto.segment.Project(r"C:\Users\aksel\Documents\Code\ethograph\data\model\project.yaml")
project.materialise()

# %%
eto.segment.se

# %%
project.update()
project.train()
# Out:
# 2026-08-23 18:18:57,629 WARNING ethograph.segment.train: 11 of 156 training samples carry no curated label for this branch (all background)
# 2026-08-23 18:18:57,629 INFO ethograph.segment.train: Samples — train: 156, val: 17, test: 173
# 2026-08-23 18:19:51,628 INFO ethograph.segment.train: [epoch 1] loss 0.0095  train acc 4.9%
# 2026-08-23 18:20:42,745 INFO ethograph.segment.train: [epoch 2] loss 0.0018  train acc 6.2%
# 2026-08-23 18:21:33,891 INFO ethograph.segment.train: [epoch 3] loss 0.0010  train acc 8.7%
# 2026-08-23 18:22:24,699 INFO ethograph.segment.train: [epoch 4] loss 0.0008  train acc 11.7%

# %%
import matplotlib.pyplot as plt
import numpy as np


path = r"C:\Users\aksel\Documents\AI_data\derivatives\sub-02_id-Poppy\ses-000_date-20260304_01\behav\Trial_data3.nc"

import ethograph as eto


dt = eto.open(path)

dt

for trial_num in dt.trials:
    trial = dt.itrial(trial_num)
    dist = trial.pellet_stickClosest_dist
    sim = trial.pellet_stickClosest_angular_similarity

    dist_vals = np.asarray(dist.values).ravel()
    sim_vals = np.asarray(sim.values).ravel()
    time_vals = np.asarray(dist.time).ravel()

    dist_bool = dist_vals < 1
    sim_bool = sim_vals > 0.5
    both_bool = dist_bool & sim_bool

    fig, (ax_dist, ax_sim, ax_both) = plt.subplots(3, 1, sharex=True, figsize=(10, 6))

    dist.plot(ax=ax_dist)
    ax_dist.axhline(1, color="gray", linestyle="--", linewidth=1)
    ax_dist.set_ylabel("distance")

    sim.plot(ax=ax_sim)
    ax_sim.axhline(0.5, color="gray", linestyle="--", linewidth=1)
    ax_sim.set_ylabel("angular sim.")

    for ax in (ax_dist, ax_sim, ax_both):
        ax.fill_between(time_vals, 0, 1, where=both_bool, transform=ax.get_xaxis_transform(),
                        color="green", alpha=0.15, step="mid")

    ax_both.plot(time_vals, both_bool, drawstyle="steps-mid")
    ax_both.set_ylim(-0.1, 1.1)
    ax_both.set_ylabel("both")
    ax_both.set_xlabel("time")

    fig.tight_layout()
    plt.show()

# %%
# This script shows how to load this in Python using PyNWB and LINDI
# It assumes you have installed PyNWB and LINDI (pip install pynwb lindi)

import pynwb
import lindi

local_cache = lindi.LocalCache()

# Load https://api.dandiarchive.org/api/assets/7f7faa37-39a5-4a4b-ae48-ea073de4ad8b/download/
f = lindi.LindiH5pyFile.from_hdf5_file("https://api.dandiarchive.org/api/assets/7f7faa37-39a5-4a4b-ae48-ea073de4ad8b/download/", local_cache=local_cache)
nwb = pynwb.NWBHDF5IO(file=f, mode='r').read()

nwb.session_description # (str) Mlost2025 benchmark batch2_1 (trial 1): four unsupervised motif tools side by side, with DeepLabCut pose and video.
nwb.identifier # (str) mlost-batch2-1-unsupervised
nwb.session_start_time # (datetime) 2024-01-01T00:00:00+00:00
nwb.file_create_date # (datetime) 2026-06-24T20:05:47.246944-06:00
nwb.timestamps_reference_time # (datetime) 2024-01-01T00:00:00+00:00
nwb.experimenter # (List[str]) ["Mlost, Jakub", "Pollak Dorocic, Iskra"]
nwb.experiment_description # (str) Novel-object-recognition test; benchmark of unsupervised behavioral segmentation tools (BFA, B-SOiD, keypoint-MoSeq, VAME), derived to ethogram bouts.
nwb.institution # (str) Stockholm University
nwb.keywords # (List[str]) ["behavior", "ethogram", "unsupervised segmentation", "benchmark", "VAME", "B-SOiD", "keypoint-MoSeq", "ndx-ethogram"]
nwb.protocol # (str) 
nwb.lab # (str) Pollak Dorocic Lab
nwb.subject # (Subject)
nwb.subject.age # (str) P0D/
nwb.subject.age__reference # (str) birth
nwb.subject.description # (str) Single mouse, novel-object-recognition test, top-down (Mlost2025 benchmark).
nwb.subject.genotype # (str) 
nwb.subject.sex # (str) U
nwb.subject.species # (str) Mus musculus
nwb.subject.subject_id # (str) mlost_batch2_1_mouse
nwb.subject.weight # (str) 
nwb.subject.date_of_birth # (datetime) 

behavior_video = nwb.acquisition["behavior_video"] # (ImageSeries) Mlost2025 NORT top-down mouse (trial 1).
# Data for behavior_video is in an external file: sub-mlost-batch2-1-mouse_ses-batch2-1_image/4ce9fc13-9b37-48d8-9549-7eed9adcf184_external_file_0.mp4
behavior_video.starting_time # 0 sec
behavior_video.rate # 25 Hz

behavior = nwb.processing["behavior"] # (ProcessingModule) Behavioral bouts and supporting modalities.

PoseEstimation = nwb.processing["behavior"]["PoseEstimation"] # (PoseEstimation) 

Skeletons = nwb.processing["behavior"]["Skeletons"] # (Skeletons) 

bfa = nwb.processing["behavior"]["bfa"] # (EthogramBouts) BFA unsupervised cluster bouts (Mlost2025 benchmark).

bfa_ethogram = nwb.processing["behavior"]["bfa_ethogram"] # (Ethogram) Behavior catalogue / coding scheme (one row per behavior type).

bfa_observed_intervals = nwb.processing["behavior"]["bfa_observed_intervals"] # (TimeIntervals) BFA labeled span; NA windowing margin excluded.
bfa_observed_intervals["id"] # (h5py.Dataset) shape [1]; dtype <i8 undefined
bfa_observed_intervals["start_time"] # (h5py.Dataset) shape [1]; dtype <f8 Start time of epoch, in seconds
bfa_observed_intervals["stop_time"] # (h5py.Dataset) shape [1]; dtype <f8 Stop time of epoch, in seconds

bsoid = nwb.processing["behavior"]["bsoid"] # (EthogramBouts) B-SOiD unsupervised cluster bouts (Mlost2025 benchmark).

bsoid_ethogram = nwb.processing["behavior"]["bsoid_ethogram"] # (Ethogram) Behavior catalogue / coding scheme (one row per behavior type).

centroid_speed = nwb.processing["behavior"]["centroid_speed"] # (TimeSeries) Per-frame speed of the pose centroid (mean over keypoints); the continuous signal the bout mean_speed / peak_speed / immobility_fraction reduce.
centroid_speed.data # (h5py.Dataset) shape [14991]; dtype <f8
centroid_speed.starting_time # 0 sec
centroid_speed.rate # 25 Hz

kpMoseq = nwb.processing["behavior"]["kpMoseq"] # (EthogramBouts) keypoint-MoSeq unsupervised cluster bouts (Mlost2025 benchmark).

kpMoseq_ethogram = nwb.processing["behavior"]["kpMoseq_ethogram"] # (Ethogram) Behavior catalogue / coding scheme (one row per behavior type).

vame = nwb.processing["behavior"]["vame"] # (EthogramBouts) VAME unsupervised cluster bouts (Mlost2025 benchmark).

vame_ethogram = nwb.processing["behavior"]["vame_ethogram"] # (Ethogram) Behavior catalogue / coding scheme (one row per behavior type).

vame_observed_intervals = nwb.processing["behavior"]["vame_observed_intervals"] # (TimeIntervals) VAME labeled span; NA windowing margin excluded.
vame_observed_intervals["id"] # (h5py.Dataset) shape [1]; dtype <i8 undefined
vame_observed_intervals["start_time"] # (h5py.Dataset) shape [1]; dtype <f8 Start time of epoch, in seconds
vame_observed_intervals["stop_time"] # (h5py.Dataset) shape [1]; dtype <f8 Stop time of epoch, in seconds
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\hdmf\build\objectmapper.py:1612, in ObjectMapper.construct(self, **kwargs)
#    1611 try:
# -> 1612     obj = self.__new_container__(cls, builder.source, parent, builder.attributes.get(self.__spec.id_key()),
#    1613                                  **kwargs)
#    1614 except Exception as ex:
#
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\hdmf\build\objectmapper.py:1625, in ObjectMapper.__new_container__(self, cls, container_source, parent, object_id, **kwargs)
#    1623 # obj has been created and is in construction mode, indicating that the object is being constructed by
#    1624 # the automatic construct process during read, rather than by the user
# -> 1625 obj.__init__(**kwargs)
# ...

# %%
from pynwb import NWBHDF5IO

path = r"C:\Users\aksel\Downloads\alignment.nwb"

io = NWBHDF5IO(path, mode="r", load_namespaces=True)
nwb = io.read()

print(nwb.trials)
print(nwb.trials.colnames)

# Access the actual trial table
df = nwb.trials.to_dataframe()
print(df)

# %%
path = r"C:\Users\aksel\.ethograph\example_data\Moll2025\Trial_data.nc"

import ethograph as eto

dt = eto.open(path)
dt.itrial(0)
# Out:
# <xarray.DatasetView> Size: 597kB
# Dimensions:               (time: 1077, space: 3, keypoint: 3, individual: 1,
#                            s3d_dims: 20, RGB: 3)
# Coordinates:
#   * time                  (time) float64 9kB 0.0 0.005 0.01 ... 5.37 5.375 5.38
#   * space                 (space) <U1 12B 'x' 'y' 'z'
#   * keypoint              (keypoint) <U8 96B 'beakTip' 'stickTip' 'pellet'
#   * individual            (individual) <U5 20B 'Crow1'
# Dimensions without coordinates: s3d_dims, RGB
# Data variables: (12/14)
#     position              (time, space, keypoint, individual) float64 78kB ...
#     confidence            (time, keypoint, individual) float32 13kB ...
#     velocity              (time, space, keypoint, individual) float64 78kB ...
#     speed                 (time, keypoint, individual) float64 26kB ...
#     acceleration          (time, space, keypoint, individual) float64 78kB ...
#     pellet_beakTip_dist   (time) float64 9kB ...
# ...

# %%
print(df)
# Out:
#       start_time    stop_time  trial                     video_cam-1  \
# id
# 0      20.938600    25.538600      1  2026-03-09_001_Poppy-cam-1.mp4
# 1      33.646233    38.491233      2  2026-03-09_002_Poppy-cam-1.mp4
# 2      46.598733    50.778733      3  2026-03-09_003_Poppy-cam-1.mp4
# 3      58.886600    62.881600      4  2026-03-09_004_Poppy-cam-1.mp4
# 4      70.989567    75.569567      5  2026-03-09_005_Poppy-cam-1.mp4
# ..           ...          ...    ...                             ...
# 153  3439.632800  3445.157800    157  2026-03-09_157_Poppy-cam-1.mp4
# 154  3453.260133  3473.290133    158  2026-03-09_158_Poppy-cam-1.mp4
# 155  3524.899800  3531.604800    159  2026-03-09_159_Poppy-cam-1.mp4
# 156  3539.711467  3552.436467    160  2026-03-09_160_Poppy-cam-1.mp4
# 157  3615.153967  3635.183967    161  2026-03-09_161_Poppy-cam-1.mp4
#
#                         video_cam-2  \
# id
# 0    2026-03-09_001_Poppy-cam-2.mp4
# 1    2026-03-09_002_Poppy-cam-2.mp4
# ...

# %%
import ethograph as eto

path = r"C:\Users\aksel\.ethograph\example_data\Moll2025\2024-12-18_041_Crow1-cam-1.mp4"

import cv2

cap = cv2.VideoCapture(path)
num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
cap.release()
print(num_frames)

path2 = r"C:\Users\aksel\.ethograph\example_data\Moll2025\Trial_data.nc"
dt = eto.open(path2)
dt.itrial(0)
# Out:
# 1077
# <xarray.DatasetView> Size: 597kB
# Dimensions:               (time: 1077, space: 3, keypoint: 3, individual: 1,
#                            s3d_dims: 20, RGB: 3)
# Coordinates:
#   * time                  (time) float64 9kB 0.0 0.005 0.01 ... 5.37 5.375 5.38
#   * space                 (space) <U1 12B 'x' 'y' 'z'
#   * keypoint              (keypoint) <U8 96B 'beakTip' 'stickTip' 'pellet'
#   * individual            (individual) <U5 20B 'Crow1'
# Dimensions without coordinates: s3d_dims, RGB
# Data variables: (12/14)
#     position              (time, space, keypoint, individual) float64 78kB ...
#     confidence            (time, keypoint, individual) float32 13kB ...
#     velocity              (time, space, keypoint, individual) float64 78kB ...
#     speed                 (time, keypoint, individual) float64 26kB ...
#     acceleration          (time, space, keypoint, individual) float64 78kB ...
#     pellet_beakTip_dist   (time) float64 9kB ...
# ...

# %%
path = r"C:\Users\aksel\Documents\AK_data\derivatives\sub-01_id-Ivy\ses-000_date-20250309_01\behav\.ethograph\alignment.nwb"

from pynwb import NWBHDF5IO

nwb = NWBHDF5IO(path, 'r').read()

# %%
nwb.trials
# Out:
# trials pynwb.epoch.TimeIntervals at 0x1451795772768
# Fields:
#   colnames: ['start_time' 'stop_time' 'trial' 'video_cam-1' 'video_cam-2' 'pose_cam-1'
#  'pose_cam-2']
#   columns: (
#     start_time <class 'hdmf.common.table.VectorData'>,
#     stop_time <class 'hdmf.common.table.VectorData'>,
#     trial <class 'hdmf.common.table.VectorData'>,
#     video_cam-1 <class 'hdmf.common.table.VectorData'>,
#     video_cam-2 <class 'hdmf.common.table.VectorData'>,
#     pose_cam-1 <class 'hdmf.common.table.VectorData'>,
#     pose_cam-2 <class 'hdmf.common.table.VectorData'>
#   )
#   description: experimental trials
#   id: id <class 'hdmf.common.table.ElementIdentifiers'>

# %%
from __future__ import annotations

from pathlib import Path

import cv2
import pandas as pd
from movement.io import load_poses


def count_mp4_frames(video_path: Path) -> int:
    capture = cv2.VideoCapture(str(video_path))
    try:
        return int(capture.get(cv2.CAP_PROP_FRAME_COUNT))
    finally:
        capture.release()


def count_pose_frames(pose_path: Path) -> int:
    dataset = load_poses.from_dlc_file(pose_path)
    return int(dataset.sizes["time"])


def find_dlc_file(video_path: Path, dlc_dir: Path) -> Path:
    matches = sorted(dlc_dir.glob(f"{video_path.stem}DLC*.h5"))
    if not matches:
        raise FileNotFoundError(f"No DLC file found for {video_path.name} in {dlc_dir}")
    return matches[0]


def add_frame_counts(
    df: pd.DataFrame,
    video_dir: Path,
    dlc_dir: Path,
    video_columns: tuple[str, ...] = ("video_cam-1", "video_cam-2"),
) -> pd.DataFrame:
    result = df.copy()
    for column in video_columns:
        video_paths = result[column].apply(lambda name: video_dir / name)
        result[f"{column}_mp4_frames"] = video_paths.apply(count_mp4_frames)
        dlc_paths = video_paths.apply(lambda p: find_dlc_file(p, dlc_dir))
        result[f"{column}_dlc_frames"] = dlc_paths.apply(count_pose_frames)
        result[f"{column}_frame_diff"] = (
            result[f"{column}_mp4_frames"] - result[f"{column}_dlc_frames"]
        )
    return result


if __name__ == "__main__":
    video_dir = Path(r"C:\Users\aksel\Documents\VidData\20260421_01_Ivy")
    dlc_dir = Path(r"E:\Backup\Akseli\AI_data\rawdata\sub-01_id-Ivy\ses-000_date-20260421_01\behav\dlc")

    df = nwb.trials.to_dataframe()
    df = add_frame_counts(df, video_dir, dlc_dir)
    print(df)
# Out:
#      start_time    stop_time  trial                   video_cam-1  \
# id
# 0     43.086400    73.131400      1  2026-04-21_001_Ivy-cam-1.mp4
# 1    105.831567   111.576567      2  2026-04-21_002_Ivy-cam-1.mp4
# 2    201.798700   214.783700      5  2026-04-21_005_Ivy-cam-1.mp4
# 3    286.387367   298.277367      6  2026-04-21_006_Ivy-cam-1.mp4
# 4    304.527433   316.347433      7  2026-04-21_007_Ivy-cam-1.mp4
# ..          ...          ...    ...                           ...
# 89  4432.139767  4446.239767    103  2026-04-21_103_Ivy-cam-1.mp4
# 90  4450.694833  4463.239833    104  2026-04-21_104_Ivy-cam-1.mp4
# 91  4469.489800  4482.124800    105  2026-04-21_105_Ivy-cam-1.mp4
# 92  4488.359733  4502.039733    106  2026-04-21_106_Ivy-cam-1.mp4
# 93  4508.294133  4521.259133    107  2026-04-21_107_Ivy-cam-1.mp4
#
#                      video_cam-2  \
# id
# 0   2026-04-21_001_Ivy-cam-2.mp4
# 1   2026-04-21_002_Ivy-cam-2.mp4
# 2   2026-04-21_005_Ivy-cam-2.mp4
# ...

# %%
from pathlib import Path

frame_count = count_mp4_frames(Path(path))
print(frame_count)
# Out:
#      start_time    stop_time  trial                   video_cam-1  \
# id
# 0     43.086400    73.131400      1  2026-04-21_001_Ivy-cam-1.mp4
# 1    105.831567   111.576567      2  2026-04-21_002_Ivy-cam-1.mp4
# 2    201.798700   214.783700      5  2026-04-21_005_Ivy-cam-1.mp4
# 3    286.387367   298.277367      6  2026-04-21_006_Ivy-cam-1.mp4
# 4    304.527433   316.347433      7  2026-04-21_007_Ivy-cam-1.mp4
# ..          ...          ...    ...                           ...
# 89  4432.139767  4446.239767    103  2026-04-21_103_Ivy-cam-1.mp4
# 90  4450.694833  4463.239833    104  2026-04-21_104_Ivy-cam-1.mp4
# 91  4469.489800  4482.124800    105  2026-04-21_105_Ivy-cam-1.mp4
# 92  4488.359733  4502.039733    106  2026-04-21_106_Ivy-cam-1.mp4
# 93  4508.294133  4521.259133    107  2026-04-21_107_Ivy-cam-1.mp4
#
#                      video_cam-2  \
# id
# 0   2026-04-21_001_Ivy-cam-2.mp4
# 1   2026-04-21_002_Ivy-cam-2.mp4
# 2   2026-04-21_005_Ivy-cam-2.mp4
# ...

# %%
print(df)
# Out:
#      start_time    stop_time  trial                   video_cam-1  \
# id
# 0     43.086400    73.131400      1  2026-04-21_001_Ivy-cam-1.mp4
# 1    105.831567   111.576567      2  2026-04-21_002_Ivy-cam-1.mp4
# 2    201.798700   214.783700      5  2026-04-21_005_Ivy-cam-1.mp4
# 3    286.387367   298.277367      6  2026-04-21_006_Ivy-cam-1.mp4
# 4    304.527433   316.347433      7  2026-04-21_007_Ivy-cam-1.mp4
# ..          ...          ...    ...                           ...
# 89  4432.139767  4446.239767    103  2026-04-21_103_Ivy-cam-1.mp4
# 90  4450.694833  4463.239833    104  2026-04-21_104_Ivy-cam-1.mp4
# 91  4469.489800  4482.124800    105  2026-04-21_105_Ivy-cam-1.mp4
# 92  4488.359733  4502.039733    106  2026-04-21_106_Ivy-cam-1.mp4
# 93  4508.294133  4521.259133    107  2026-04-21_107_Ivy-cam-1.mp4
#
#                      video_cam-2  \
# id
# 0   2026-04-21_001_Ivy-cam-2.mp4
# 1   2026-04-21_002_Ivy-cam-2.mp4
# 2   2026-04-21_005_Ivy-cam-2.mp4
# ...

# %%
df = nwb.trials.to_dataframe()
df
# Out:
#      start_time    stop_time  trial                   video_cam-1  \
# id
# 0     43.086400    73.131400      1  2026-04-21_001_Ivy-cam-1.mp4
# 1    105.831567   111.576567      2  2026-04-21_002_Ivy-cam-1.mp4
# 2    201.798700   214.783700      5  2026-04-21_005_Ivy-cam-1.mp4
# 3    286.387367   298.277367      6  2026-04-21_006_Ivy-cam-1.mp4
# 4    304.527433   316.347433      7  2026-04-21_007_Ivy-cam-1.mp4
# ..          ...          ...    ...                           ...
# 89  4432.139767  4446.239767    103  2026-04-21_103_Ivy-cam-1.mp4
# 90  4450.694833  4463.239833    104  2026-04-21_104_Ivy-cam-1.mp4
# 91  4469.489800  4482.124800    105  2026-04-21_105_Ivy-cam-1.mp4
# 92  4488.359733  4502.039733    106  2026-04-21_106_Ivy-cam-1.mp4
# 93  4508.294133  4521.259133    107  2026-04-21_107_Ivy-cam-1.mp4
#
#                      video_cam-2  \
# id
# 0   2026-04-21_001_Ivy-cam-2.mp4
# 1   2026-04-21_002_Ivy-cam-2.mp4
# 2   2026-04-21_005_Ivy-cam-2.mp4
# ...
