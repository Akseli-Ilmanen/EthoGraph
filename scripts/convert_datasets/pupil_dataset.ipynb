# %%
# Out:
# ...
# SHA256 hash of downloaded file: e24645639acbcf5f51a2eef9774524fc6ce4319ee68b6ee6f86303ad80473beb
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.

# %%
from movement import sample_data
from ethograph.utils.io import minimal_dt_from_pose

ds = sample_data.fetch_dataset(
    "DLC_rotating-mouse_eye-tracking_stim-black.predictions.h5",
    with_video=True,
)
ds.to_netcdf("DLC_rotating-mouse_eye-tracking_stim-black.trial.nc")



dt = minimal_dt_from_pose(video_path=r"C:\Users\aksel\Documents\Code\EthoGraph\data\pupil\video.mp4",
                          fps=60,
                          tracking_path=r"C:\Users\aksel\Documents\Code\EthoGraph\data\pupil\pose.h5",
                          source_software="DeepLabCut")
                          
                          

dt.to_netcdf(r"C:\Users\aksel\Documents\Code\EthoGraph\data\pupil\trial.nc")
# Out:
# 2026-01-12 22:48:25.049 | WARNING  | xarray.core.utils:emit_user_level_warning:1268 - <string>:3: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# Extracted type_vars_dict: {'individuals': array(['individual_0'], dtype='<U12'), 'features': ['position', 'confidence'], 'cameras': array(['cam1'], dtype='<U4'), 'tracking': array(['DeepLabCut_11'], dtype='<U13'), 'keypoints': array(['pupil-L', 'pupil-R', 'eye-L', 'eye-R'], dtype='<U7'), 'trial_conditions': []}
