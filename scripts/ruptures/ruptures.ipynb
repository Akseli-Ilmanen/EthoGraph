# %%
import crowsetta

scribe = crowsetta.Transcriber(format='aud-seq')
annot = scribe.from_file('my_annotation.audacity.txt').to_annot()

# annot.seq is a Sequence, annot.annot_path is the file path
print(annot)
# Annotation(annot_path=PosixPath('...'), notated_path=None, seq=<Sequence with 42 segments>)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import crowsetta
#       3 scribe = crowsetta.Transcriber(format='aud-seq')
# ----> 4 annot = scribe.from_file('my_annotation.audacity.txt').to_annot()
#       6 # annot.seq is a Sequence, annot.annot_path is the file path
#       7 print(annot)
#
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\crowsetta\transcriber.py:203, in Transcriber.from_file(self, annot_path, *args, **kwargs)
#     143 def from_file(
#     144     self, annot_path, *args, **kwargs
#     145 ) -> "Union[crowsetta.interface.SeqLike,crowsetta.interface.BBoxLike]":  # noqa: F821
#     146     """Load annotations from a file.
#     147
#     148     Parameters
#    (...)    201     >>> generic_seq.to_csv('./data/bfsongrepo/notmats.csv')
#     202     """
# --> 203     return self._format_class.from_file(annot_path, *args, **kwargs)
#
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\crowsetta\formats\seq\audseq.py:183, in AudSeq.from_file(cls, annot_path, notated_path)
#     181 annot_path = pathlib.Path(annot_path)
#     182 crowsetta.validation.validate_ext(annot_path, extension=cls.ext)
# --> 183 df = pd.read_csv(annot_path, sep="\t", header=None)
#     184 df.columns = ["start_time", "end_time", "label"]
#     185 df = AudSeqSchema.validate(df)
#
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\aksel\anaconda3\envs\ethograph\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_annotation.audacity.txt'

# %%
import numpy as np

seq = crowsetta.Sequence.from_keyword(
    onset_samples=np.array([0, 1000, 2000]),
    offset_samples=np.array([999, 1999, 2999]),
    onsets_s=np.array([0.0, 1.0, 2.0]),
    offsets_s=np.array([0.999, 1.999, 2.999]),
    labels=np.array(['walk', 'peck', 'fly']),
)

# %%
seq.segments[0]
# Segment(label='walk', onset_s=0.0, offset_s=0.999, ...)

seq.segments[0].label      # 'walk'
seq.segments[0].onset_s    # 0.0
seq.segments[0].offset_s   # 0.999seq
# Out:
# np.float64(0.999)

# %% [markdown]
# # Basic usage
#
# <!-- {{ add_binder_block(page) }} -->
#
# Let us start with a simple example to illustrate the use of `ruptures`: generate a 3-dimensional piecewise constant signal with noise and estimate the change points.
#
# ## Setup
# First, we make the necessary imports.

# %%
import matplotlib.pyplot as plt  # for display purposes

import ruptures as rpt  # our package

# %% [markdown]
# ## Generate and display the signal
#
# Let us generate a 3-dimensional piecewise constant signal with Gaussian noise.

# %%
n_samples, n_dims, sigma = 1000, 3, 2
n_bkps = 4  # number of breakpoints
signal, bkps = rpt.pw_constant(n_samples, n_dims, n_bkps, noise_std=sigma)

# %% [markdown]
# The true change points of this synthetic signal are available in the `bkps` variable.

# %%
print(bkps)
# Out:
# [207, 399, 616, 805, 1000]

# %% [markdown]
# Note that the first four element are change point indexes while the last is simply the number of samples.
# (This is a technical convention so that functions in `ruptures` always know the length of the signal at hand.)
#
# It is also possible to plot our \(\mathbb{R}^3\)-valued signal along with the true change points with the `rpt.display` function.
# In the following image, the color changes whenever the mean of the signal shifts.

# %%
path = r"C:\Users\aksel\Documents\Code\EthoGraph\tests\test_data\copExpBP08_trim.nc"

from ethograph import TrialTree

dt = TrialTree.open(path)

signal = dt.itrial(0).isel(individuals=0)["vibration (accelerometer)"].values
dt.itrial(0).isel(individuals=0)["vibration (accelerometer)"].plot()

# %%
import numpy as np

pens = np.logspace(1, 10, 20)
n_bkps = []
for pen in pens:
    bkps = algo.predict(pen=pen)
    n_bkps.append(len(bkps) - 1)

plt.plot(pens, n_bkps, "o-")
plt.xscale("log")
plt.xlabel("Penalty")
plt.ylabel("Number of changepoints")
# Out:
# Text(0, 0.5, 'Number of changepoints')

# %%
from ethograph.features.filter import envelope

rate = dt.itrial(0).audio_sr
env_rate = 500

env = envelope(signal, rate=rate, cutoff=env_rate/4, env_rate=env_rate)
plt.figure(figsize=(20, 10))
plt.plot(env)

# %%
# detection
algo = rpt.Pelt(model="l2").fit(env)

bkps = algo.predict(pen=10**8)

fig, ax_array = rpt.display(env, bkps, figsize=(15, 5))

# %% [markdown]
# ## Change point detection
# We can now perform change point detection, meaning that we find the indexes where the signal mean changes.
# To that end, we minimize the sum of squared errors when approximating the signal by a piecewise constant signal.
# Formally, for a signal \( y_0 , y_1 , \dots , y_{T-1} \) (\( T \) samples), we solve the following optimization problem, over all possible change positions \( t_1 < t_2 < \dots < t_K \)
# where the number \( K \) of changes is defined by the user:
#
# \[
#     \hat{t}_1, \hat{t}_2,\dots,\hat{t}_K = \arg\min_{t_1,\dots,t_K} V(t_1,t_2,\dots,t_K)
# \]
#
# with
#
# \[
#     V(t_1,t_2,\dots,t_K) := \sum_{k=0}^K\sum_{t=t_k}^{t_{k+1}-1} \|y_t-\bar{y}_{t_k..t_{k+1}}\|^2
# \]
#
#
# where \( \bar{y}_{t_k..t_{k+1}} \) is the empirical mean of the sub-signal \( y_{t_k}, y_{t_k+1},\dots,y_{t_{k+1}-1} \).
# (By convention \( t_0=0 \) and \( t_{K+1}=T \).)
#
# This optimization is solved with dynamic programming, using the [`Dynp`](../user-guide/detection/dynp.md) class. (More information in the section [What is change point detection?](/what-is-cpd) and the [User guide](/user-guide).)

# %%
# detection
algo = rpt.Dynp(model="l2").fit(signal)
result = algo.predict(n_bkps=4)

print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # detection
# ----> 2 algo = rpt.Dynp(model="l2").fit(signal)
#       3 result = algo.predict(n_bkps=4)
#       5 print(result)
#
# NameError: name 'rpt' is not defined

# %% [markdown]
# Again the first elements are change point indexes and the last is the number of samples.

# %% [markdown]
# ## Display the results

# %% [markdown]
# To visualy compare the true segmentation (`bkps`) and the estimated one (`result`), we can resort to `rpt.display` a second time.
# In the following image, the alternating colors indicate the true breakpoints and the dashed vertical lines, the estimated breakpoints.

# %%
import numpy as np

# %%
# display
rpt.display(signal, bkps, result)
plt.show()

# %% [markdown]
# In this simple example, both are quite similar and almost undistinguishable.
