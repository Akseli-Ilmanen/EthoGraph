# %%
paths = [r"C:\Users\Admin\Documents\Akseli\AI_data\derivatives\sub-03_id-Freddy\ses-000_date-20250526_01\behav\Trial_data.nc",
         r"C:\Users\Admin\Documents\Akseli\AI_data\derivatives\sub-03_id-Freddy\ses-001_date-20250527_01\behav\Trial_data.nc",
         r"C:\Users\Admin\Documents\Akseli\AI_data\derivatives\sub-03_id-Freddy\ses-002_date-20250527_02\behav\Trial_data.nc",
         r"C:\Users\Admin\Documents\Akseli\AI_data\derivatives\sub-03_id-Freddy\ses-003_date-20250528_01\behav\Trial_data.nc"]



from ethograph.utils.io import TrialTree

merge_dict = {}
dt = TrialTree.load(path)
for i, path in enumerate(paths):
    dt_temp = TrialTree.load(path)
    
    merge_dict[f"session_{i}"] = dt_temp


dt = TrialTree.merge_session_trees(merge_dict)
ds = dt.stack_session(
    concat_dim="trials",
    keep_vars=["labels", "speed"],
    # attrs_to_vars=["poscat", "num_pellets"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6 merge_dict = {}
#       7 dt = TrialTree.load(path)
# ----> 8 for i, path in enumerate(paths):
#       9     dt_temp = TrialTree.load(path)
#      11     merge_dict[f"session_{i}"] = dt_temp
#
# NameError: name 'paths' is not defined

# %%
label_dt = dt.get_label_dt()
label_dt
# Out:
# <xarray.DataTree>
# Group: /
# ├── Group: /trial_1
# │       Dimensions:      (time: 1135, individuals: 1)
# │       Coordinates:
# │         * time         (time) float64 9kB 0.0 0.005 0.01 0.015 ... 5.66 5.665 5.67
# │         * individuals  (individuals) <U6 24B 'Freddy'
# │       Data variables:
# │           labels       (time, individuals) float64 9kB ...
# │       Attributes: (12/17)
# │           source_software:  DeepLabCut
# │           ds_type:          poses
# │           fps:              200.0
# │           time_unit:        seconds
# │           source_file:      D:/Alice/AK_data/rawdata/sub-03_id-Freddy/ses-000_date-...
# │           trial:            1
# │           ...               ...
# │           cam2_file:        2025-05-28_001_Freddy-cam-2.mp4
# │           dlc1_file:        2025-05-28_001_Freddy-cam-1DLC_resnet50_Felix_cross_Ses...
# │           dlc2_file:        2025-05-28_001_Freddy-cam-2DLC_resnet50_Felix_cross_Ses...
# │           poscat:           3
# ...
